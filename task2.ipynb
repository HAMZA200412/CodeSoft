# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from  sklearn.preprocessing import StandardScaler

# %%
df=pd.read_csv(r"C:\Users\USER\Downloads\t2.csv", encoding='latin-1')
df
# Out:
#                                      Name    Year Duration            Genre  \
# 0                                             NaN      NaN            Drama
# 1      #Gadhvi (He thought he was Gandhi)  (2019)  109 min            Drama
# 2                             #Homecoming  (2021)   90 min   Drama, Musical
# 3                                 #Yaaram  (2019)  110 min  Comedy, Romance
# 4                       ...And Once Again  (2010)  105 min            Drama
# ...                                   ...     ...      ...              ...
# 15504                 Zulm Ko Jala Doonga  (1988)      NaN           Action
# 15505                               Zulmi  (1999)  129 min    Action, Drama
# 15506                           Zulmi Raj  (2005)      NaN           Action
# 15507                       Zulmi Shikari  (1988)      NaN           Action
# 15508                        Zulm-O-Sitam  (1998)  130 min    Action, Drama
#
# ...

# %%
df.dtypes
# Out:
# Name         object
# Year         object
# Duration     object
# Genre        object
# Rating      float64
# Votes        object
# Director     object
# Actor 1      object
# Actor 2      object
# Actor 3      object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Name           0
# Year         528
# Duration    8269
# Genre       1877
# Rating      7590
# Votes       7589
# Director     525
# Actor 1     1617
# Actor 2     2384
# Actor 3     3144
# dtype: int64

# %%
df.drop_duplicates()
# Out:
#                                      Name    Year Duration            Genre  \
# 0                                             NaN      NaN            Drama
# 1      #Gadhvi (He thought he was Gandhi)  (2019)  109 min            Drama
# 2                             #Homecoming  (2021)   90 min   Drama, Musical
# 3                                 #Yaaram  (2019)  110 min  Comedy, Romance
# 4                       ...And Once Again  (2010)  105 min            Drama
# ...                                   ...     ...      ...              ...
# 15504                 Zulm Ko Jala Doonga  (1988)      NaN           Action
# 15505                               Zulmi  (1999)  129 min    Action, Drama
# 15506                           Zulmi Raj  (2005)      NaN           Action
# 15507                       Zulmi Shikari  (1988)      NaN           Action
# 15508                        Zulm-O-Sitam  (1998)  130 min    Action, Drama
#
# ...

# %%
df.drop(["Actor 2","Actor 3"],axis=1,inplace=True)

# %%
df["Year"]=df["Year"].str.lstrip("(")
df["Year"]=df["Year"].str.rstrip(")")
df["Year"]=df["Year"].astype("float")

# %%
df["Duration"]=df["Duration"].str.rstrip(" min")
df["Duration"]=df["Duration"].astype("float")

# %%
df["Duration"]=df["Duration"].fillna(df["Duration"].mean())

# %%
df.dropna(subset=['Year'], inplace=True)

# %%
df["Votes"] = df["Votes"].str.replace(',', '.')
df["Votes"] = df["Votes"].str.replace('M', '')
df["Votes"] = df["Votes"].str.replace('$', '').astype(float)
df["Votes"]=df["Votes"].fillna(df["Votes"].mean())

# %%
df3 = df[df['Rating'].isnull()]
df3
# Out:
#                     Name    Year    Duration                   Genre  Rating  \
# 2            #Homecoming  2021.0   90.000000          Drama, Musical     NaN
# 4      ...And Once Again  2010.0  105.000000                   Drama     NaN
# 7         .in for Motion  2008.0   59.000000             Documentary     NaN
# 14            101 Ratein  1990.0  128.126519                Thriller     NaN
# 17       108 Teerthyatra  1987.0  128.126519  Comedy, Drama, Fantasy     NaN
# ...                  ...     ...         ...                     ...     ...
# 15499      Zulm Ka Jawab  1995.0  128.126519                  Action     NaN
# 15500    Zulm Ka Muqabla  1993.0  128.126519                  Action     NaN
# 15502      Zulm Ki Pukar  1979.0  128.126519                  Action     NaN
# 15506          Zulmi Raj  2005.0  128.126519                  Action     NaN
# 15507      Zulmi Shikari  1988.0  128.126519                  Action     NaN
#
# ...

# %%
df2=df.dropna(subset=['Rating'],axis=0)
df2
# Out:
#                                      Name    Year    Duration  \
# 1      #Gadhvi (He thought he was Gandhi)  2019.0  109.000000
# 3                                 #Yaaram  2019.0  110.000000
# 5                    ...Aur Pyaar Ho Gaya  1997.0  147.000000
# 6                               ...Yahaan  2005.0  142.000000
# 8                      ?: A Question Mark  2012.0   82.000000
# ...                                   ...     ...         ...
# 15501                     Zulm Ki Hukumat  1992.0  128.126519
# 15503                     Zulm Ki Zanjeer  1989.0  125.000000
# 15504                 Zulm Ko Jala Doonga  1988.0  128.126519
# 15505                               Zulmi  1999.0  129.000000
# 15508                        Zulm-O-Sitam  1998.0  130.000000
#
#                            Genre  Rating    Votes           Director  \
# 1                          Drama     7.0    8.000      Gaurav Bakshi
# 3                Comedy, Romance     4.4   35.000         Ovais Khan
# ...

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# %%
x=df2[["Year","Duration","Votes"]]
y=df2["Rating"]
#scaler = StandardScaler()
#x = scaler.fit_transform(x)
#x3=scaler.fit_transform(df3[["Year","Duration","Votes"]])
poly_features = PolynomialFeatures(degree=2, include_bias=False)
x_poly = poly_features.fit_transform(x)
x3_poly = poly_features.transform(df3[["Year","Duration","Votes"]])
poly_reg = LinearRegression()
poly_reg.fit(x_poly, y)
y_pred = poly_reg.predict(x3_poly)

# %%
y_pred
# Out:
# array([6.19473946, 5.75267125, 6.6395944 , ..., 5.78453483, 5.50473545,
#        5.62340835])

# %%
df3["Rating"]=y_pred
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_5692\2987795069.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["Rating"]=y_pred

# %%
df3
# Out:
#                     Name    Year    Duration                   Genre  \
# 2            #Homecoming  2021.0   90.000000          Drama, Musical
# 4      ...And Once Again  2010.0  105.000000                   Drama
# 7         .in for Motion  2008.0   59.000000             Documentary
# 14            101 Ratein  1990.0  128.126519                Thriller
# 17       108 Teerthyatra  1987.0  128.126519  Comedy, Drama, Fantasy
# ...                  ...     ...         ...                     ...
# 15499      Zulm Ka Jawab  1995.0  128.126519                  Action
# 15500    Zulm Ka Muqabla  1993.0  128.126519                  Action
# 15502      Zulm Ki Pukar  1979.0  128.126519                  Action
# 15506          Zulmi Raj  2005.0  128.126519                  Action
# 15507      Zulmi Shikari  1988.0  128.126519                  Action
#
#          Rating       Votes            Director                Actor 1
# ...

# %%
df= pd.concat([df2, df3], axis=0)

df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#                                      Name    Year    Duration  \
# 0      #Gadhvi (He thought he was Gandhi)  2019.0  109.000000
# 1                                 #Yaaram  2019.0  110.000000
# 2                    ...Aur Pyaar Ho Gaya  1997.0  147.000000
# 3                               ...Yahaan  2005.0  142.000000
# 4                      ?: A Question Mark  2012.0   82.000000
# ...                                   ...     ...         ...
# 14976                       Zulm Ka Jawab  1995.0  128.126519
# 14977                     Zulm Ka Muqabla  1993.0  128.126519
# 14978                       Zulm Ki Pukar  1979.0  128.126519
# 14979                           Zulmi Raj  2005.0  128.126519
# 14980                       Zulmi Shikari  1988.0  128.126519
#
#                            Genre    Rating       Votes         Director  \
# 0                          Drama  7.000000    8.000000    Gaurav Bakshi
# 1                Comedy, Romance  4.400000   35.000000       Ovais Khan
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x=df[["Year","Duration","Votes"]]
y=df["Rating"]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
poly_features = PolynomialFeatures(degree=9, include_bias=False)
x_train_poly = poly_features.fit_transform(x_train)
x_test_poly = poly_features.transform(x_test)
poly_reg = LinearRegression()
poly_reg.fit(x_train_poly, y_train)
y_pred = poly_reg.predict(x_test_poly)

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
mse = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error: {mse}')
r2 = r2_score(y_test, y_pred)
print(f'R-squared: {r2}')
# Out:
# Mean Squared Error: 0.9041487807106461
# R-squared: 0.2902186411854951
